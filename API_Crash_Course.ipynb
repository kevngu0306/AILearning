# %% [markdown]
# <a href="https://colab.research.google.com/github/kevngu0306/AILearning/blob/main/API_Crash_Course.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests

# %%
# REST API Crash Course - Caleb Curry

import requests
import json


# ***CONSUME THE STACKOVERFLOW API***
response = requests.get("https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow")

print(response)
print(response.json())
print(response.json()["items"])

print()

# This for loop prints each item's (question's) title and link
# for data in response.json()["items"]:
#  print(data["title"])
#  print(data["link"])
#  print()

# This for loop prints unanswered items' (questions') title and link
for data in response.json()["items"]:
  if(data["answer_count"] == 0):
    print(data["title"])
    print(data["link"])
    print()
  else:
    print("Skipped.")
    print()


# ***SETTING UP OUR OWN PYTHON API***
# Out:
# <Response [200]>
# ...
